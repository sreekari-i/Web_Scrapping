# %% [markdown]
# # Web Scrapping Assignment 4<br><br><br><br>

# %%
# Installing the selenium library
! pip install selenium

# %%
# Importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import time

# %%
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing necessary packages
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Installing requests
! pip install requests

# %%
# Setting display options for the dataframe
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 500
pd. set_option('display.width', 10000)

# %% [markdown]
# ### <br><br><br> 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# <br>You need to find following details:<br>
# A) Rank<br>
# B) Name<br>
# C) Artist<br>
# D) Upload date<br>
# E) Views<br><br>

# %%
# lets first  connect to webdriver
driver1= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url1= "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/"
driver1.get(url1)

# %%
search_link= driver1.find_elements_by_xpath('//*[@id="noarticletext"]/tbody/tr/td/ul/li[2]/span/a')[0]
search_link.click()

# %%
selecting_link= driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[3]/ul/li[1]/div[1]/a')[0]
selecting_link.click()

# %%
rank = driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[1]')

# %%
name = driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[2]')

# %%
artist = driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[3]')

# %%
upload_date = driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[5]')

# %%
views = driver1.find_elements_by_xpath('//*[@id="mw-content-text"]/div[1]/table[3]/tbody/tr/td[4]')

# %%
print(len(rank), len(name), len(artist), len(upload_date), len(views))
# Out:
# 30 30 30 30 30

# %%
# appending lists
details_1 = []
for i in range(len(rank)):
        details_1.append([rank[i].text, name[i].text, artist[i].text, upload_date[i].text, views[i].text])

# %%
# creating dataframe
df1 = pd.DataFrame(details_1, columns =['Rank', 'Name', 'Artist', 'Uploaded Date', 'Views'])  
df1
# Out:
#    Rank                                             Name                          Artist      Uploaded Date Views
# 0    1.                           "Baby Shark Dance"[22]  Pinkfong Kids' Songs & Stories      June 17, 2016  8.71
# 1    2.                                  "Despacito"[24]                      Luis Fonsi   January 12, 2017  7.38
# 2    3.                       "Johny Johny Yes Papa"[25]                     LooLoo Kids    October 8, 2016  5.41
# 3    4.                               "Shape of You"[26]                      Ed Sheeran   January 30, 2017  5.34
# 4    5.                              "See You Again"[27]                     Wiz Khalifa      April 6, 2015  5.13
# 5    6.   "Masha and the Bear – Recipe for Disaster"[30]                      Get Movies   January 31, 2012  4.44
# 6    7.                                "Uptown Funk"[31]                     Mark Ronson  November 19, 2014  4.19
# ...

# %% [markdown]
# ### <br><br><br>2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.<br>
# You need to find following details:<br>
# A) Match title (I.e. 1st ODI)<br>
# B) Series<br>
# C) Place<br>
# D) Date<br>
# E) Time<br>
# Note: - From bcci.tv home page you have reach to the international fixture page through code.<br><br>

# %%
# lets first  connect to webdriver
driver2= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url2= "https://www.bcci.tv/"
driver2.get(url2)

# %%
# selecting international fixtures
selecting_link2= driver2.find_elements_by_xpath('/html/body/footer/div/nav/ul/li[2]/ul/li[1]/a')[0]
selecting_link2.click()

# %%
title= driver2.find_elements_by_xpath('/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[1]/span[2]')

# %%
series = driver2.find_elements_by_xpath('/html/body/div[4]/div/div/div[2]/section/div/div/a/div[3]')

# %%
place= driver2.find_elements_by_xpath('/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[2]/p/span')

# %%
date=driver2.find_elements_by_xpath('/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[2]/span/strong')

# %%
time=driver2.find_elements_by_xpath('/html/body/div[4]/div/div/div[2]/section/div/div/a/div[1]/div/div/span[2]')

# %%
print(len(title), len(series), len(place), len(date), len(time))
# Out:
# 6 6 6 6 6

# %%
# appending lists
details_2 = []
for i in range(len(title)):
        details_2.append([title[i].text, series[i].text.replace('\n', ' '), place[i].text, date[i].text, time[i].text])

# %%
# creating dataframe
df2 = pd.DataFrame(details_2, columns =['Title', 'Series', 'Place', 'Date', 'Time'])  
df2
# Out:
#                          Title               Series                        Place Date       Time
# 0  ICC WORLD TEST CHAMPIONSHIP  INDIA v NEW ZEALAND  The Ageas Bowl, Southampton       15:00 IST
# 1         ENGLAND V INDIA 2021      ENGLAND v INDIA     Trent Bridge, Nottingham       15:30 IST
# 2         ENGLAND V INDIA 2021      ENGLAND v INDIA               Lord's, London       15:30 IST
# 3         ENGLAND V INDIA 2021      ENGLAND v INDIA            Headingley, Leeds       15:30 IST
# 4         ENGLAND V INDIA 2021      ENGLAND v INDIA             The Oval, London       15:30 IST
# 5         ENGLAND V INDIA 2021      ENGLAND v INDIA     Old Trafford, Manchester       15:30 IST

# %% [markdown]
# ### <br><br><br> 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/<br>
# You need to find following details:<br>
# A) Name<br>
# B) Description<br>
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.<br><br>

# %%
# lets first  connect to webdriver
driver3= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url3= "https://www.guru99.com/"
driver3.get(url3)

# %%
from selenium.common.exceptions import InvalidElementStateException
from selenium.common.exceptions import ElementNotInteractableException

# %%
from selenium.webdriver.common.keys import Keys

# %%
search_button3= driver3.find_elements_by_xpath('//*[@id="java_technologies"]/li[3]/a')[0]
search_button3.click()

# %%
# accessing required link
reqd_link =  driver3.find_elements_by_xpath('//*[@id="g-mainbar"]/div/div/div/div/div/div/div[2]/table[5]/tbody/tr[34]/td[1]/a/strong')[0]
reqd_link.click()

# %%
name3= driver3.find_elements_by_xpath('//*[@id="g-mainbar"]/div[1]/div/div/div/div/div/div[2]/table/tbody/tr/td[1]')[1:]

# %%
desc3= driver3.find_elements_by_xpath('//*[@id="g-mainbar"]/div[1]/div/div/div/div/div/div[2]/table/tbody/tr/td[2]')[1:]

# %%
print(len(name3), len(desc3))
# Out:
# 41 41

# %%
# appending lists
details_3 = []
for i in range(len(name3)):
        details_3.append([name3[i].text, desc3[i].text])

# %%
# creating dataframe
df3 = pd.DataFrame(details_3, columns =['Exception Name', 'Description'])  
df3
# Out:
#                          Exception Name                                                                                                                                                     Description
# 0            ElementNotVisibleException                                                             This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.
# 1         ElementNotSelectableException               This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.
# 2                NoSuchElementException                                                                                                         This Exception occurs if an element could not be found.
# ...

# %% [markdown]
# ### <br><br><br> 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/<br>
# You have to find following details:<br>
# A) Rank<br>
# B) State<br>
# C) GSDP at current price (19-20)<br>
# D) GSDP at current price (18-19)<br>
# E) Share(18-19)<br>
# F) GDP($ billion)<br>
# Note: - From statisticstimes home page you have to reach to economy page through code.<br><br>

# %%
# lets first  connect to webdriver
driver4= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url4= "http://statisticstimes.com/"
driver4.get(url4)

# %%
drop_page4= driver4.find_elements_by_xpath('//*[@id="top"]/div[2]/div[2]/button')[0]
drop_page4.click()

# %%
search_india= driver4.find_elements_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')[0]
search_india.click()

# %%
gdp_ind= driver4.find_elements_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')[0]
gdp_ind.click()

# %%
rank4= driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[1]')
state4 =driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[2]')
gsdp_19 =driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[3]')
gsdp_18 =driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[4]')
share_18 =driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[5]')
gdp_ =driver4.find_elements_by_xpath('//*[@id="table_id"]/tbody/tr/td[6]')

# %%
# appending lists
details_4 = []
for i in range(len(rank4)):
        details_4.append([rank4[i].text, state4[i].text, gsdp_19[i].text, gsdp_18[i].text, share_18[i].text, gdp_[i].text])

# %%
# creating dataframe
df4 = pd.DataFrame(details_4, columns =['Rank', 'State', 'GSDP at current price (19-20)', 'GSDP at current price (18-19)', ' Share(18-19)', ' GDP($ billion)'])  
df4
# Out:
#    Rank                      State GSDP at current price (19-20) GSDP at current price (18-19)  Share(18-19)  GDP($ billion)
# 0     1                Maharashtra                             -                     2,632,792        13.94%         399.921
# 1     2                 Tamil Nadu                     1,845,853                     1,630,208         8.63%         247.629
# 2     3              Uttar Pradesh                     1,687,818                     1,584,764         8.39%         240.726
# 3     4                    Gujarat                             -                     1,502,899         7.96%         228.290
# 4     5                  Karnataka                     1,631,977                     1,493,127         7.91%         226.806
# 5     6                West Bengal                     1,253,832                     1,089,898         5.77%         165.556
# ...

# %% [markdown]
# ### <br><br><br>5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/<br>
# You have to find the following details:<br>
# A) Repository title<br>
# B) Repository description<br>
# C) Contributors count<br>
# D) Language used<br>
# Note: - From the home page you have to click on the trending option from Explore menu through code<br><br>

# %%
# lets first  connect to webdriver
driver5= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url5= "https://github.com/"
driver5.get(url5)

# %%
explore= driver5.find_elements_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')[0]
explore.click()

trending= driver5.find_elements_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a')[0]
trending.click()

# %%
title5= driver5.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/h1/a')

# %%
description5 =  driver5.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/p')

# %%
lang_5 =driver5.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/div[2]/span[1]/span[2]')
count5 =driver5.find_elements_by_xpath('//*[@id="js-pjax-container"]/div[3]/div/div[2]/article/div[2]/span[2]')

# %%
# appending lists
details_5 = []
for i in range(len(lang_5)):
        details_5.append([title5[i].text, description5[i].text, lang_5[i].text, count5[i].text])

# %%
# creating dataframe
df5 = pd.DataFrame(details_5, columns =['Repository title', 'Repository Description', 'Language', 'Contributors language'])  
df5
# Out:
#                          Repository title                                                                                                              Repository Description          Language Contributors language
# 0              madMAx43v3r / chia-plotter                                                                                        Model parallel transformers in JAX and Haiku                 C              Built by
# 1                 peng-zhihui / XUAN-Bike                                                               A complete computer science study plan to become a software engineer.  Jupyter Notebook       656 stars today
# 2       kingoflolz / mesh-transformer-jax                                                          Node.js library to automate Chromium, Firefox and WebKit with a single API        TypeScript              Built by
# ...

# %% [markdown]
# ### <br><br><br>6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/<br>
# You have to find the following details:<br>
# A) Song name<br>
# B) Artist name<br>
# C) Last week rank<br>
# D) Peak rank<br>
# E) Weeks on board<br>
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.<br><br>

# %%
# lets first  connect to webdriver
driver6= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url6= "https://www.billboard.com/"
driver6.get(url6)


# clicking on charts
charts= driver6.find_elements_by_xpath('//*[@id="root"]/div[2]/div[2]/header/div/ul/li[1]/a')[0]
charts.click()


# accessing hot 100 songs list
hot_100= driver6.find_elements_by_xpath('//*[@id="main"]/div[2]/div/div[1]/a/div[2]/div[2]/div[1]')[0]
hot_100.click()

# %%
# scraping required data

# %%
song_name = driver6.find_elements_by_xpath('//*[@id="charts"]/div/div[7]/div/ol/li/button/span[2]/span[1]')

# %%
artist = driver6.find_elements_by_xpath('//*[@id="charts"]/div/div[7]/div/ol/li/button/span[2]/span[2]')

# %%
l_week_rank = driver6.find_elements_by_xpath('//*[@id="charts"]/div/div[7]/div/ol/li/button/div/div[2]')

# %%
peak_rank = driver6.find_elements_by_xpath('//*[@id="charts"]/div/div[7]/div/ol/li/button/div/div[3]')

# %%
# appending lists
details_6 = []
for i in range(len(song_name)):
        details_6.append([song_name[i].text, artist[i].text, l_week_rank[i].text, peak_rank[i].text])

# %%
weeks_on_board = driver6.find_elements_by_xpath('//*[@id="charts"]/div/div[7]/div/ol/li/button/span[2]/span[3]/span[3]')

# %%
weeks = []
for i in range(len(weeks_on_board)):
    weeks.append(weeks_on_board[i].text.replace('WoC', ""))

# %%
# creating dataframe
df6 = pd.DataFrame(details_6, columns =['Song Name', 'Artist Name', 'Last Week Rank', 'Peak Rank'])

# %%
df6['Weeks on Board'] = weeks

# %%
df6
# Out:
#                             Song Name                                     Artist Name Last Week Rank Peak Rank Weeks on Board
# 0                              Butter                                             BTS              1         3             3
# 1                            Good 4 U                                  Olivia Rodrigo              2         1             4
# 2                          Levitating                       Dua Lipa Featuring DaBaby              3         2            36
# 3                             Peaches  Justin Bieber Featuring Daniel Caesar & Giveon              1        12            12
# 4                 Leave The Door Open        Silk Sonic (Bruno Mars & Anderson .Paak)              1        14            14
# 5                     Save Your Tears                      The Weeknd & Ariana Grande              1        26            26
# ...

# %% [markdown]
# ### <br><br><br>7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/<br>
# You have to find the following details:<br>
# A) Name<br>
# B) Designation<br>
# C) Company<br>
# D) Skills they hire for<br>
# E) Location<br>
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code<br><br>

# %%
# lets first  connect to webdriver
driver7= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url7= "https://www.naukri.com/"
driver7.get(url7)

# %%
recruiters= driver7.find_elements_by_xpath('//*[@id="root"]/div[1]/div/ul[1]/li[2]/a/div')[0]
recruiters.click()

# %%
# recruiters url
url_7 = "https://www.naukri.com/hr-recruiters-consultants"
driver7.get(url_7)


# creating input bar
user_inp7=input('Enter job role: ')

# accessing the searchbar
search_bar7= driver7.find_element_by_name('qp')
search_bar7.clear()
# Out:
# Enter job role: Data Science

# %%
#sending keys to the search bar
search_bar7.send_keys(user_inp7)

# clicking the search icon
search_button7= driver7.find_elements_by_id('qsbFormBtn')[0]
search_button7.click()

# %%
name7 = driver7.find_elements_by_xpath('//*[@id="tabP-1"]/div/div[2]/div[1]/div[1]/p/a[1]/span')
designation7 = driver7.find_elements_by_xpath('//*[@id="tabP-1"]/div/div[2]/div[1]/div[1]/p/span[1]')
company7 = driver7.find_elements_by_xpath('//*[@id="tabP-1"]/div/div[2]/div[1]/div[1]/p/a[2]')
skills7 = driver7.find_elements_by_xpath('//*[@id="tabP-1"]/div/div[2]/div[1]/div[2]')
loc7 = driver7.find_elements_by_xpath('//*[@id="tabP-1"]/div/div[2]/div[1]/div[1]/p/span[2]/small')

# %%
# appending lists
details_7 = []
for i in range(len(loc7)):
        details_7.append([name7[i].text, designation7[i].text, company7[i].text, skills7[i].text, loc7[i].text])

# %%
# creating dataframe
df7 = pd.DataFrame(details_7, columns =['Name of the recruiter', 'Designation', 'Company Name', 'Skills they hire for', 'Job Location'])  
df7
# Out:
#                            Name of the recruiter                          Designation                                 Company Name                                                                                                                                            Skills they hire for              Job Location
# 0                           shravan Kumar Gaddam                    Company Recruiter                Shore Infotech India Pvt. Ltd        .Net, Java, Data Science, Linux Administration, Sql Server Development, Winforms, Wcf Services, Wpf, Telecom Engineering, Technical Management, Software  Hyderabad / Secunderabad
# 1                                   Anik Agrawal                    Company Recruiter        Enerlytics Software Solutions Pvt Ltd                       Mean Stack, javascript, angularjs, mongodb, Web Services, rest, express, Node.js, Big Data, iot, Data Science, Cloud Computing, saas, Aws                 Ahmedabad
# ...

# %% [markdown]
# ### <br><br><br> 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/<br>
# You have to find the following details:<br>
# A) Book name<br>
# B) Author name<br>
# C) Volumes sold<br>
# D) Publisher<br>
# E) Genre<br><br>

# %%
# lets first  connect to webdriver
driver8= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url8= "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/"
driver8.get(url8)

# %%
# Page not formed, unable to fetch the data

# %% [markdown]
# ### <br><br><br> 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/<br>
# You have to find the following details:<br>
# A) Name<br>
# B) Year span<br>
# C) Genre<br>
# D) Run time<br>
# E) Ratings<br>
# F) Votes<br><br>

# %%
# lets first  connect to webdriver
driver9= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url9= " https://www.imdb.com/list/ls095964455/ "
driver9.get(url9)

# %%
name9 = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/h3/a')
year_span = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/h3/span[2]')
genre9 = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/p[1]/span[5]')
run_time = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/p[1]/span[3]')
ratings9 = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/div/div[1]/span[2]')
votes9 = driver9.find_elements_by_xpath('//*[@id="main"]/div/div[3]/div[3]/div/div[2]/p[4]/span[2]')

# %%
# appending lists
details_9 = []
for i in range(len(name9)):
        details_9.append([name9[i].text, year_span[i].text, genre9[i].text, run_time[i].text, ratings9[i].text, votes9[i].text])

# %%
# creating dataframe
df9 = pd.DataFrame(details_9, columns =['Name', 'Year', 'Genre', 'Run Time', 'Ratings', 'Votes'])  
df9
# Out:
#                               Name         Year                         Genre Run Time Ratings      Votes
# 0                  Game of Thrones  (2011–2019)      Action, Adventure, Drama   57 min     9.3  1,823,368
# 1                  Stranger Things     (2016– )        Drama, Fantasy, Horror   51 min     8.7    863,891
# 2                 The Walking Dead  (2010–2022)       Drama, Horror, Thriller   44 min     8.2    874,519
# 3                   13 Reasons Why  (2017–2020)      Drama, Mystery, Thriller   60 min     7.6    262,696
# 4                          The 100  (2014–2020)        Drama, Mystery, Sci-Fi   43 min     7.6    224,039
# 5          Orange Is the New Black  (2013–2019)          Comedy, Crime, Drama   59 min       8    282,664
# 6                        Riverdale     (2017– )         Crime, Drama, Mystery   45 min     6.8    125,050
# 7                   Grey's Anatomy     (2005– )                Drama, Romance   41 min     7.5    261,192
# ...

# %% [markdown]
# ### <br><br><br>10. Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/<br>
#  You have to find the following details:<br>
# A) Dataset name<br>
# B) Data type<br>
# C) Task<br>
# D) Attribute type<br>
# E) No of instances<br>
# F) No of attribute<br>
# G) Year<br>
# Note: - from the home page you have to go to the Show All Dataset page through code.<br><br>

# %%
# lets first  connect to webdriver
driver10= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url10= " https://archive.ics.uci.edu/ "
driver10.get(url10)

# %%
all_datasets= driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a')[0]
all_datasets.click()

# %%
d_name = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a')
d_type = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p')
task10 = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p')
attr_type = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p')
n_instances = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p')
n_attr = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p')
year10 = driver10.find_elements_by_xpath('/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p')

# %%
# appending lists
details_10 = []
for i in range(len(d_name)):
        details_10.append([d_name[i].text, d_type[i].text, task10[i].text, attr_type[i].text, n_instances[i].text, n_attr[i].text, year10[i].text])

# %%
# creating dataframe
df10 = pd.DataFrame(details_10, columns =['Dataset Name', 'Datatype', 'Task', 'Attribute type', 'No of instances', ' No of attribute', 'Year'])  
df10[1:]
# Out:
#                                                                                   Dataset Name                                               Datatype                                            Task               Attribute type No of instances  No of attribute   Year
# 1                                                                                        Adult                                          Multivariate                                  Classification   Categorical, Integer, Real            4177                8   1995
# 2                                                                                    Annealing                                          Multivariate                                  Classification         Categorical, Integer           48842               14   1996
# ...
