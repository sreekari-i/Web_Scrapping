# %% [markdown]
# # Web Scrapping Assignment 3

# %%
# Installing the selenium library
! pip install selenium

# %%
# Importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver
import time

# %%
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing necessary packages
from webdriver_manager.chrome import ChromeDriverManager

# %%
# Installing requests
! pip install requests

# %%
# Setting display options for the dataframe
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 500
pd. set_option('display.width', 10000)

# %% [markdown]
# ### <br><br><br> (Q1)<br>   Write a python program which searches all the  product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.<br>

# %%
# lets first  connect to webdriver
driver1= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url1= "https://www.amazon.in/"
driver1.get(url1)

# creating input bar
user_inp1=input('Enter name of the item: ')

# accessing the searchbar
search_bar1= driver1.find_element_by_id('twotabsearchtextbox')
search_bar1.clear()

#sending keys to the search bar
search_bar1.send_keys(user_inp1)

# clicking the search icon
search_button1= driver1.find_elements_by_id('nav-search-submit-button')[0]
search_button1.click()
# Out:
# Enter name of the item: Guitar

# %% [markdown]
# ### <br><br><br>(Q2)<br> In the above question, now scrape the following details of each product listed in first 3 pagesof your search results and save it in a dataframe and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that productvertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.
# <br>

# %%
# for holding the resultant list
element_list2 = []
  
for page in range(1, 4, 1):
    
    page_url2 = "https://www.amazon.in/s?k=Guitar&page=&qid=1622995375&ref=sr_pg_2" + str(page)
    driver1 = webdriver.Chrome(ChromeDriverManager().install())
    driver1.get(page_url2)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# There is no [win32] chromedriver for browser 91.0.4472 in cache
# Get LATEST driver version for 91.0.4472
# Trying to download new driver from https://chromedriver.storage.googleapis.com/91.0.4472.19/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\91.0.4472.19]
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache

# %%
name = driver1.find_elements_by_xpath("//span[@class='a-size-base-plus a-color-base a-text-normal']")

# %%
price = driver1.find_elements_by_xpath("//span[@class='a-price-whole']")
rating = driver1.find_elements_by_xpath("//span[@class='a-icon-alt']")
expected_delivery = driver1.find_elements_by_xpath("//span[@class='a-text-bold']")

# %%
for i in range(len(rating)):
        element_list2.append([name[i].text, price[i].text, rating[i].text, expected_delivery[i].text])

# %%
# creating dataframe
df2 = pd.DataFrame(element_list2, columns =['Name', 'Price', 'Rating', 'Expected Delivery'])  
df2
# Out:
#                                                                                                                                                                                                         Name   Price Rating  Expected Delivery
# 0                                                                       Kadence Frontier Jumbo Semi Acoustic Guitar With Die Cast Keys Super Combo (Bag, 1 pack Strings, Strap, Picks, Capo, Tuner (natural)   2,799           Sunday, June 13
# 1                                                                                Kadence Frontier Series,Blue Acoustic Guitar With Die Cast Keys Super Combo,Tuner,Capo,Bag,strap,strings,Stand and 3 picks)   3,499           Sunday, June 13
# 2                                                              Kadence Slowhand Premium Jumbo Size Semi Acoustic Guitar with Heavy Padded Bag, guitar cable, Pro Capo and Fibre guitar stand (Mahagony Wood)   4,999           Sunday, June 13
# ...

# %% [markdown]
# ### <br><br><br>3. **Write a python program to access the search bar and search button on images.google.com and scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.**<br>

# %%
# lets first  connect to webdriver
driver3= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")


url3= "https://images.google.com/?gws_rd=ssl"
driver3.get(url3)

user_inp3=input('Enter name of the item that you would like to get images: ')


# accessing the searchbar
search_bar3= driver3.find_element_by_name('q')
search_bar3.clear()

search_bar3.send_keys(user_inp3)

search_button3= driver3.find_elements_by_class_name('Tg7LZd')[0]
search_button3.click()




fruits_images=[]
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver3.execute_script('return document.body.scrollHeight')
while True:
    driver3.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver3.execute_script('return document.body.scrollHeight')
    try:
        driver3.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div/div[5]/input').click()
        time.sleep(2)
    except:
        pass
    if new_height == last_height:
        break
    last_height = new_height


for i in range(1, 100):
    try:
        fruits_images.append(driver3.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').screenshot('Untitled Folder ('+str(i)+').png'))
    except:
        pass
# images will be stored in the path selected i.e, in the selected location in the computer
# Out:
# Enter name of the item that you would like to get images: Fruits

# %%
# lets first  connect to webdriver
driver3= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")


url3= "https://images.google.com/?gws_rd=ssl"
driver3.get(url3)

user_inp3=input('Enter name of the item that you would like to get images: ')


# accessing the searchbar
search_bar3= driver3.find_element_by_name('q')
search_bar3.clear()

search_bar3.send_keys(user_inp3)

search_button3= driver3.find_elements_by_class_name('Tg7LZd')[0]
search_button3.click()




cars_images=[]
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver3.execute_script('return document.body.scrollHeight')
while True:
    driver3.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver3.execute_script('return document.body.scrollHeight')
    try:
        driver3.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div/div[5]/input').click()
        time.sleep(2)
    except:
        pass
    if new_height == last_height:
        break
    last_height = new_height


for i in range(1, 100):
    try:
        cars_images.append(driver3.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').screenshot('Untitled_Folder1 ('+str(i)+').png'))
    except:
        pass
# images will be stored in the path selected i.e, in the selected location in the computer
# Out:
# Enter name of the item that you would like to get images: cars

# %%
# lets first  connect to webdriver
driver3= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")


url3= "https://images.google.com/?gws_rd=ssl"
driver3.get(url3)

user_inp3=input('Enter name of the item that you would like to get images: ')


# accessing the searchbar
search_bar3= driver3.find_element_by_name('q')
search_bar3.clear()

search_bar3.send_keys(user_inp3)

search_button3= driver3.find_elements_by_class_name('Tg7LZd')[0]
search_button3.click()




ml_images=[]
#Will keep scrolling down the webpage until it cannot scroll no more
last_height = driver3.execute_script('return document.body.scrollHeight')
while True:
    driver3.execute_script('window.scrollTo(0,document.body.scrollHeight)')
    time.sleep(2)
    new_height = driver3.execute_script('return document.body.scrollHeight')
    try:
        driver3.find_element_by_xpath('//*[@id="islmp"]/div/div/div/div/div[5]/input').click()
        time.sleep(2)
    except:
        pass
    if new_height == last_height:
        break
    last_height = new_height


for i in range(1, 100):
    try:
        ml_images.append(driver3.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').screenshot('Untitled-Folder2 ('+str(i)+').png'))
    except:
        pass
# images will be stored in the path selected i.e, in the selected location in the computer
# Out:
# Enter name of the item that you would like to get images: Machine learning

# %% [markdown]
# ### <br><br><br> 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page.<br>
# Details to be scraped:<br> “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.<br>
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
# lets first  connect to webdriver
driver4= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")


url4= "https://www.flipkart.com/"
driver4.get(url4)

sleep(4)

# %%
skip_login = driver4.find_element_by_xpath('/html/body/div[2]/div/div/button')
skip_login.click()

# %%
user_inp4=input('Enter name of the item that you would like to search: ')


search_bar4= driver4.find_element_by_name('q')
search_bar4.clear()

search_bar4.send_keys(user_inp4)
# Out:
# Enter name of the item that you would like to search: redmi note 10 pro

# %%
# accessing the searchbar
search_button4= driver4.find_elements_by_class_name('L0Z3Pu')[0]
search_button4.click()

# %%
name = driver4.find_elements_by_class_name("_4rR01T")

# %%
price = driver4.find_elements_by_class_name("_25b18c")

# %%
rating = driver4.find_elements_by_class_name("_3LWZlK")

# %%
memory = driver4.find_elements_by_xpath("//li[1][@class='rgWa7D']")

# %%
display = driver4.find_elements_by_xpath("//li[2][@class='rgWa7D']")

# %%
camera = driver4.find_elements_by_xpath("//li[3][@class='rgWa7D']")

# %%
battery =driver4.find_elements_by_xpath("//li[4][@class='rgWa7D']")

# %%
processor =driver4.find_elements_by_xpath("//li[5][@class='rgWa7D']")

# %%
warranty =driver4.find_elements_by_xpath("//li[6][@class='rgWa7D']")

# %%
# Scrapping urls

# for holding the resultant list
url_list = []
  
url = driver4.find_elements_by_xpath("//a[@class='_1fQZEK']")
    
  
for i in range(len(url)):
        url_list.append(url[i].get_attribute('href'))

# %%
phone_details = []
for i in range(len(warranty)):
        phone_details.append([name[i].text, price[i].text, rating[i].text, memory[i].text, display[i].text, camera[i].text, battery[i].text, processor[i].text, warranty[i].text, url_list[i] ])

# %%
# creating dataframe
df4 = pd.DataFrame(phone_details, columns =['Name', 'Price', 'Rating', 'Memory', 'Display', 'Camera', 'Battery', 'Processor', 'Warranty', 'Product URL'])  
df4
# Out:
#                                               Name                   Price Rating                                          Memory                                Display                                                  Camera                           Battery                                                                                                                                        Processor                                                                                                                                         Warranty                                                                                                                                                                                                                                                                                                                                                                                            Product URL
# ...

# %%
# converting to csv file
df4.to_csv('phone_details.csv')

# %%
# loading the csv file
df41=pd.read_csv('phone_details.csv')
df41
# Out:
#     Unnamed: 0                                            Name                   Price  Rating                                          Memory                                Display                                                  Camera                           Battery                                                                                                                                        Processor                                                                                                                                         Warranty                                                                                                                                                                                                                                                                                                                                                                                            Product URL
# ...

# %% [markdown]
# ### <br><br><br> 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# lets first  connect to webdriver
driver5= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

url5= "https://www.google.com/maps/"
driver5.get(url5)

# creating input bar
user_inp5=input('Enter City Name: ')

# accessing the search bar of the webpage
search_bar5= driver5.find_element_by_id("searchboxinput")
search_bar5.clear()
search_bar5.send_keys(user_inp5)

# clicking the search icon
search_button5= driver5.find_elements_by_id('searchbox-searchbutton')[0]
search_button5.click()

# fetching the url of the 
url_loc= driver5.current_url

# replacing values other than geospatial coordinates
x= url_loc.replace('https://www.google.com/maps/@','').replace(',12z','')

# printing the geospatial coordinates
print(" Geospatial coordinates(Latitude,Longitude) are"+" "+x)
# Out:
# Enter City Name: Hyderabad
#  Geospatial coordinates(Latitude,Longitude) are 17.5276032,78.4826368

# %% [markdown]
# ### <br><br><br>6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in.

# %%
# lets first  connect to webdriver
driver6= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url6= "https://trak.in/india-startup-funding-investment-2015/"
driver6.get(url6)

# %%
funding_deals = []

# %%
date=driver6.find_elements_by_xpath("//*[@class='column-2']")[55:85]

# %%
startup_name=driver6.find_elements_by_xpath("//*[@class='column-3']")[55:85]

industry=driver6.find_elements_by_xpath("//*[@class='column-4']")[55:85]

sub_vertical=driver6.find_elements_by_xpath("//*[@class='column-5']")[55:85]

city=driver6.find_elements_by_xpath("//*[@class='column-6']")[55:85]

investor_name=driver6.find_elements_by_xpath("//*[@class='column-7']")[55:85]

investment_type=driver6.find_elements_by_xpath("//*[@class='column-8']")[55:85]

amount=driver6.find_elements_by_xpath("//*[@class='column-9']")[55:85]

# %%
date_list = []
for i in date:
        date_list.append(i.text)

# %%
startup_list = []
for i in startup_name:
    sleep(4)
    startup_list.append(i.text)

# %%
industry_list = []
for i in industry:
        industry_list.append(i.text)

# %%
sub_vertical_list = []
for i in sub_vertical:
        sub_vertical_list.append(i.text)

# %%
city_list = []
for i in city:
        city_list.append(i.text)

# %%
investor_name_list = []
for i in investor_name:
        investor_name_list.append(i.text)

# %%
investment_type_list = []
for i in investment_type:
        investment_type_list.append(i.text)

# %%
amount_list = []
for i in amount:
        amount_list.append(i.text)

# %%
# creating dataframe
funding_deals = pd.DataFrame({'Date': date_list, 'Start Up Name': startup_list, 'Industry': industry_list, 'Sub Vertical':sub_vertical_list, 'City': city_list, 'Investor Name':investor_name_list, 'Investment Type': investment_type_list, 'Amount':amount_list})
funding_deals
# Out:
#           Date              Start Up Name                                Industry                                               Sub Vertical                                        City                                                                                       Investor Name         Investment Type           Amount
# 0   08/09/2020                     Byju’s                                 EduTech                                            Online Tutoring                                   Bangalore                                        Silver Lake, Tiger Global, General Atlantic and Owl Ventures          Private Equity      500,000,000
# 1   12/09/2020                  mCaffeine                           Personal Care                                        Skincare & Haircare                                      Mumbai  Amicus Capital Private Equity I LLP, Amicus Capital Partners India Fund I and RP-SG Venture Fund 1                Series B        3,000,000
# ...

# %% [markdown]
# ### <br><br><br>7. Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
# lets first  connect to webdriver
driver7= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# url of the amazon.in
url7= "https://www.digit.in/"
driver7.get(url7)

# %%
search_7= driver7.find_element_by_xpath('/html/body/div[1]/div[2]/div[3]/div[2]/a/img').click()

from selenium.webdriver.common.keys import Keys
element= driver7.find_element_by_id('globalPageSearchText')

element.send_keys("gaming laptop")
element.send_keys(Keys.ENTER)

# %%
top_10 = driver7.find_element_by_xpath('//*[@id="content_top10"]').click()

# %%
top_10_laptops_list = driver7.find_element_by_xpath('/html/body/div[6]/div[2]/div[2]/div[4]/a/div').click()

# %%
name = driver7.find_elements_by_xpath('//*[@id="summtable"]/tbody/tr/td[1]')

# %%
seller = driver7.find_elements_by_xpath('//*[@id="summtable"]/tbody/tr/td[2]')

# %%
price = driver7.find_elements_by_xpath('//*[@id="summtable"]/tbody/tr/td[3]')

# %%
laptop_details = []
for i in range(len(name)):
        laptop_details.append([name[i].text, seller[i].text, price[i].text])

# %%
# creating dataframe
df7 = pd.DataFrame(laptop_details, columns =['Name', 'Seller', 'Price'])  
df7
# Out:
#                        Name  Seller    Price
# 0     Alienware Area 51M R2     N/A      N/A
# 1          Alienware m15 R3     N/A  ₹341990
# 2    ASUS ROG Strix Scar 15     N/A      N/A
# 3     Asus ROG Zephyrus G14  amazon  ₹164990
# 4          Lenovo Legion 5i     N/A   ₹71990
# 5  ASUS ROG ZEPHYRUS DUO 15  amazon  ₹199990
# 6      Acer Aspire 7 gaming     N/A   ₹56990
