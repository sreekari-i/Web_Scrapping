# %% [markdown]
# # Web_Scrapping_Assignment_2(Selenium) <br><br>

# %%
# Installing the selenium library
! pip install selenium

# %%
# Importing the required libraries
import selenium
import pandas as pd
from selenium import webdriver

# %%
pip install webdriver_manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing necessary packages
from webdriver_manager.chrome import ChromeDriverManager

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 500
pd. set_option('display.width', 10000)

# %% [markdown]
# ### <br><br><br> 1: Write a python program to scrape data for “Data Analyst” Job position in“Bangalore” location. You have to scrape the job-title, job-location, company_name,experience_required. You have to scrape first 10 jobs data.

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url= " https://www.naukri.com/ "
driver.get(url)

# %%
# finding element by job search bar
search_job=driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ddb11fe0361589fa0fc88c328f4e4704", element="697b40eb-4cbf-4637-a800-573eee55b762")>

# %%
# write on search bar
search_job.send_keys("Data Analyst")

# %%
#finding element for jb location bar
search_loc=driver.find_element_by_id('qsb-location-sugg')
search_loc
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="ddb11fe0361589fa0fc88c328f4e4704", element="3257cfd8-a18d-4876-b46f-ecd6a26da462")>

# %%
search_loc.send_keys("Bangalore")

# %%
title=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
job_loc=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")

# %%
com_name=driver.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
exp_=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span")

# %%
element_list1 = []
for i in range(len(title)):
        element_list1.append([title[i].text, job_loc[i].text, com_name[i].text, exp_[i].text])

# %%
len(element_list1)
# Out:
# 20

# %%
new_element_list1 = element_list1[:10]

# %%
# Creating DataFrame
df1 = pd.DataFrame(new_element_list1, columns =['Job Title', 'Location', 'Company Name', 'Experience'])  
df1
# Out:
#                                                              Job Title                                                                              Location                                            Company Name Experience
# 0                      Data Scientist / Data Analyst -Business Analyst  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru                      Inflexion Analytix Private Limited    0-3 Yrs
# 1                                       Data Analyst - Informatica MDM                                                                   Bangalore/Bengaluru                     Shell India Markets Private Limited    6-9 Yrs
# 2  Assistant Vice President - MIS & Reporting ( Business Data Analyst)                                                           Mumbai, Bangalore/Bengaluru  INTERTRUSTVITEOS CORPORATE AND FUND SERVICES PVT. LTD.  12-18 Yrs
# ...

# %% [markdown]
# # <br><br><br> Q2: Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, full job-description. You have to scrape first 10 jobs data.

# %%
# lets first  connect to webdriver
driver2= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url1= " https://www.naukri.com/ "
driver2.get(url1)

# %%
# finding element by job search bar
search_job1=driver2.find_element_by_id('qsb-keyword-sugg')
search_job1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4aafd4dcf4f3a822668665b7fe560c88", element="105da9de-8e3d-4e62-8956-da6059c16116")>

# %%
# write on search bar
search_job1.send_keys("Data Scientist")

# %%
#finding element for jb location bar
search_loc1=driver2.find_element_by_id('qsb-location-sugg')
search_loc1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4aafd4dcf4f3a822668665b7fe560c88", element="1611031c-640f-46a2-9c19-ac13a10da469")>

# %%
search_loc1.send_keys("Bangalore")

# %%
# Scrapping urls

# for holding the resultant list
element_list21 = []
  
description2 = driver2.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
    
  
for i in range(len(description2)):
        element_list21.append(description2[i].get_attribute('href'))
  
print(element_list21)
# Out:
# ['https://www.naukri.com/job-listings-data-scientist-data-analyst-business-analyst-inflexion-analytix-private-limited-mumbai-hyderabad-secunderabad-pune-gurgaon-gurugram-chennai-bangalore-bengaluru-0-to-3-years-100521000368?src=jobsearchDesk&sid=16216679490869436&xp=1&px=1', 'https://www.naukri.com/job-listings-data-scientist-wipro-limited-kolkata-hyderabad-secunderabad-chennai-bangalore-bengaluru-4-to-9-years-210521000038?src=jobsearchDesk&sid=16216679490869436&xp=2&px=1', 'https://www.naukri.com/job-listings-big-data-data-scientist-xoriant-solutions-pvt-ltd-kochi-cochin-indore-hyderabad-secunderabad-pune-ahmedabad-bangalore-bengaluru-mumbai-all-areas-1-to-3-years-130521005018?src=jobsearchDesk&sid=16216679490869436&xp=3&px=1', 'https://www.naukri.com/job-listings-specialist-i-data-scientist-philips-india-limited-bangalore-bengaluru-4-to-7-years-170521500993?src=jobsearchDesk&sid=16216679490869436&xp=4&px=1', 'https://www.naukri.com/job-listings-data-scientist-ibm-india-pvt-limited-
# ...

# %% [markdown]
# ### <br><br><br> Q3: In this question you have to scrape data using the filters available on the webpage.

# %% [markdown]
# * You have to use the location and salary filter.
# * You have to scrape data for “Data Scientist” designation for first 10 job results.
# * You have to scrape the job-title, job-location, company_name, experience_required.
# * The location filter to be used is “Delhi/NCR”
# * The salary filter to be used is “3-6” lakhs

# %%
# lets first  connect to webdriver
driver3= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url3= " https://www.naukri.com/ "
driver3.get(url3)

# %%
# finding element by job search bar
search_job_3=driver3.find_element_by_id('qsb-keyword-sugg')
search_job_3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f2edc3e02c33e98b6228937d519e5bfd", element="62864276-3977-4e5d-8875-6786a91ff6d9")>

# %%
# write on search bar
search_job_3.send_keys("Data Scientist")

# %%
#applying Location filter
loc_filter=driver3.find_elements_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[2]/div[2]/div[2]/label/p/span[1]")[0].click()

# %%
# applying salary filter
sal=driver3.find_elements_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[2]/label/p/span[1]")[0].click()

# %%
title3=driver3.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")

# %%
job_location=driver3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span")

# %%
company_name=driver3.find_elements_by_xpath("//a[@class='subTitle ellipsis fleft']")

# %%
experience_required=driver3.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span")

# %%
element_list3 = []
for i in range(len(title3)):
        element_list3.append([title3[i].text, job_location[i].text, company_name[i].text, experience_required[i].text])

# %%
len(element_list3)
# Out:
# 20

# %%
new_element_list3 = element_list3[:10]

# %%
# Creating DataFrame
df3 = pd.DataFrame(new_element_list3, columns =['Job Title', 'Location', 'Company Name', 'Experience Required'])  
df3
# Out:
#                                                        Job Title                                                                                     Location                                               Company Name Experience Required
# 0                Data Scientist / Data Analyst -Business Analyst         Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/Gurugram, Chennai, Bangalore/Bengaluru                         Inflexion Analytix Private Limited             0-3 Yrs
# 1                               Business Analyst- Data Scientist                                                                      Noida, Gurgaon/Gurugram                                                      Wipro             2-5 Yrs
# 2  Data Scientist - High growth VC backed Influencer Marketplace                                         Bangalore/Bengaluru, Delhi / NCR, Mumbai (All Areas)                            Ravgins International Pvt. Ltd.             3-5 Yrs
# ...

# %% [markdown]
# # <br><br><br> Q4: Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company.

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url4= " https://www.glassdoor.co.in/index.htm "
driver.get(url4)

# %%
search_job4=driver.find_elements_by_class_name('d-flex col SearchStyles__searchKeywordContainer')

# %%
search_job4.send_keys("Data Scientist")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-29fcc76fb0ee> in <module>
# ----> 1 search_job4.send_keys("Data Scientist")
#
# AttributeError: 'list' object has no attribute 'send_keys'

# %%
search_loc4=driver.find_element_by_id('sc.location')
search_loc4
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="01482eac62d12457b0fad76d0109c04e", element="f7f786c5-01af-4419-85a2-0625a73ddde1")>

# %%
search_loc4.send_keys("Noida")

# %%
com_name4 = driver.find_elements_by_xpath("/html/body/div[3]/div/div/div[1]/div/div[2]/section/article/div[1]/ul/li[1]/div[2]/div[1]/a/span")

# %%
no_of_days_ago4 = driver.find_elements_by_xpath("/html/body/div[3]/div/div/div[1]/div/div[2]/section/article/div[1]/ul/li[1]/div[2]/div[3]/div[2]/div[2]")[0:]

# %%
rating4 = driver.find_elements_by_xpath("/html/body/div[3]/div/div/div[1]/div/div[2]/section/article/div[1]/ul/li[1]/div[1]/span")

# %%
no_of_days_ago4
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="01482eac62d12457b0fad76d0109c04e", element="e43cfd09-7ff5-4dfa-8f23-99125a694f74")>]

# %%
element_list4 = []
for i in range(len(com_name4)):
        element_list4.append([com_name4[i].text, no_of_days_ago4[i].text, rating4[i].text])

# %%
element_list4
# Out:
# [['Midland Credit Management, Inc.', '24h', '3.8']]

# %%
d-flex justify-content-between align-items-start

# %%
com_name4 = driver.find_elements_by_xpath("//div[@class=' d-flex justify-content-between align-items-start ']")

# %%
com_name4
# Out:
# []

# %%
page_url4 = "https://www.glassdoor.co.in/Job/noida-data-scientist-jobs-SRCH_IL.0,5_IC4477468_KO6,20.htm"
driver4 = webdriver.Chrome(ChromeDriverManager().install())
driver4.get(page_url4)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache

# %%
title4 = driver4.find_elements_by_xpath("//span[@id='MainCol']/div[1]/ul/li[1]/div[2]/div[1]/a")

# %%
title4
# Out:
# []

# %% [markdown]
# # <br><br><br> Q5: Write a python program to scrape the salary data for Data Scientist designation in Noida location.

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url5= " https://www.glassdoor.co.in/Salaries/index.htm "
driver.get(url5)

# %%
search_job3=driver.find_element_by_id('KeywordSearch')
search_job3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="63dec787a1aa46cbaf52e9df7f5c12a1", element="077d588a-0501-49df-bd54-105130c9a575")>

# %%
# write on search bar
search_job3.send_keys("Data Scientist")

# %%
search_loc5=driver.find_element_by_id('LocationSearch')
search_loc5
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="63dec787a1aa46cbaf52e9df7f5c12a1", element="2bb0ee8b-b60a-4311-be8b-cab31f7af868")>

# %%
search_loc5.send_keys("Noida")

# %%
min_sal = driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']/span[1]")

# %%
max_sal = driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']/span[2]")

# %%
comp_name = driver.find_elements_by_xpath("//p[@class='m-0 ']")

# %%
avg_sal = driver.find_elements_by_xpath("//div[@class='col-2 d-none d-md-flex flex-row justify-content-end']/strong")

# %%
element_list5 = []
for i in range(len(min_sal)):
        element_list5.append([min_sal[i].text, max_sal[i].text, comp_name[i].text, avg_sal[i].text])

# %%
element_list5
# Out:
# [['₹343K', '₹1,250K', 'Tata Consultancy Services', '₹ 6,14,306'],
#  ['₹577K', '₹2,213K', 'Accenture', '₹ 11,46,533'],
#  ['₹586K', '₹2,730K', 'IBM', '₹ 8,97,795'],
#  ['₹355K', '₹1,613K', 'Ericsson-Worldwide', '₹ 7,38,057'],
#  ['₹450K', '₹11,622K', 'Delhivery', '₹ 12,39,781'],
#  ['₹1,069K', '₹1,520K', 'UnitedHealth Group', '₹ 13,36,142'],
#  ['₹502K', '₹1,465K', 'Valiance Solutions', '₹ 8,15,192'],
#  ['₹202K', '₹1,809K', 'ZS Associates', '₹ 11,35,221'],
#  ['₹575K', '₹1,520K', 'EXL Service', '₹ 11,44,243'],
#  ['₹1,014K', '₹2,149K', 'Optum Global Solutions', '₹ 14,13,288'],
#  ['₹620K', '₹1,695K', 'Innovaccer', '₹ 12,07,110'],
#  ['₹792K', '₹1,263K', 'Cognizant Technology Solutions', '₹ 10,07,410'],
#  ['₹807K', '₹1,986K', 'Optum', '₹ 13,18,851'],
#  ['₹405K', '₹1,703K', 'Tech Mahindra', '₹ 10,52,718'],
#  ['₹971K', '₹1,883K', 'OYO', '₹ 14,13,078'],
#  ['₹400K', '₹1,124K', 'Nagarro', '₹ 9,61,653'],
#  ['₹817K', '₹2,006K', 'dunnhumby', '₹ 11,00,000'],
# ...

# %%
new_element_list5 = element_list5[0:10]

# %%
len(new_element_list5)
# Out:
# 10

# %%
# Creating DataFrame
df5 = pd.DataFrame(new_element_list5, columns =['Minimum Salary', 'Maximum Salary', 'Company Name', 'Average Salary'])  
df5
# Out:
#   Minimum Salary Maximum Salary               Company Name Average Salary
# 0          ₹343K        ₹1,250K  Tata Consultancy Services     ₹ 6,14,306
# 1          ₹577K        ₹2,213K                  Accenture    ₹ 11,46,533
# 2          ₹586K        ₹2,730K                        IBM     ₹ 8,97,795
# 3          ₹355K        ₹1,613K         Ericsson-Worldwide     ₹ 7,38,057
# 4          ₹450K       ₹11,622K                  Delhivery    ₹ 12,39,781
# 5        ₹1,069K        ₹1,520K         UnitedHealth Group    ₹ 13,36,142
# 6          ₹502K        ₹1,465K         Valiance Solutions     ₹ 8,15,192
# 7          ₹202K        ₹1,809K              ZS Associates    ₹ 11,35,221
# 8          ₹575K        ₹1,520K                EXL Service    ₹ 11,44,243
# 9        ₹1,014K        ₹2,149K     Optum Global Solutions    ₹ 14,13,288

# %% [markdown]
# # <br><br><br> Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# 1. Brand
# 2. Product Description
# 3. Price
# 4. Discount %

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url6= "  https://www.flipkart.com/ "
driver.get(url6)

# %%
search_item=driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search_item
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b3eb5faff7bf437bac91944c13eef996", element="5f5a6133-c879-404b-bbf7-7e50473091ae")>

# %%
# write on search bar
search_item.send_keys("sunglasses")

# %%
# for holding the resultant list
element_list6 = []
  
for page in range(1, 4, 1):
    
    page_url6 = "https://www.flipkart.com/search?q=sunglasses&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=" + str(page)
    driver6 = webdriver.Chrome(ChromeDriverManager().install())
    driver6.get(page_url6)
    title6 = driver6.find_elements_by_xpath("//div[@class='_2WkVRV']")
    description6 = driver6.find_elements_by_xpath("//a[@target='_blank']")
    price6 = driver6.find_elements_by_xpath("//div[@class='_30jeq3']")
    discount6 = driver6.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")

  
    for i in range(len(discount6)):
        element_list6.append([title6[i].text, description6[i].text, price6[i].text, discount6[i].text])
  
print(element_list6)
  
#closing the driver
driver6.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
new_element_list_6=element_list6[0:100]

# %%
len(new_element_list_6)
# Out:
# 100

# %%
# creating dataframe
df6 = pd.DataFrame(new_element_list_6, columns =['Brand Name', 'Description', 'Price(in Rs.)', 'Discount'])  
df6.head(100)
# Out:
#           Brand Name                                                 Description Price(in Rs.) Discount
# 0           bulgaria                                                                      ₹449  55% off
# 1            ROADWAY                   Others Rectangular Sunglasses (Free Size)          ₹294  80% off
# 2           Fastrack                                             ₹449₹99955% off          ₹630  21% off
# 3     ROZZETTA CRAFT                                                                      ₹499  77% off
# 4           Fastrack  UV Protection Retro Square, Sports Sunglasses (Free Siz...          ₹733  18% off
# 5           Fastrack                      ₹294₹1,49980% off\nOr Pay ₹279 + \n 15          ₹758  15% off
# 6             PIRASO                                                                      ₹250  84% off
# 7           Fastrack            UV Protection Rectangular Sunglasses (Free Size)          ₹621  22% off
# ...

# %% [markdown]
# # <br><br><br> Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link:
# https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace.

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url7= " https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace "
driver.get(url7)

# %%
# Extracting first two pages

# for holding the resultant list
element_list7 = []
  
for page in range(1, 3, 1):
    
    page_url7 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    driver7 = webdriver.Chrome(ChromeDriverManager().install())
    driver7.get(page_url7)
    rating7 = driver7.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    review7 = driver7.find_elements_by_xpath("//p[@class='_2-N8zT']")
    full_review7 = driver7.find_elements_by_xpath("//div[@class='t-ZTKy']")
  
    for i in range(len(rating7)):
        element_list7.append([rating7[i].text, review7[i].text, full_review7[i].text])
  
print(element_list7)
  
#closing the driver
driver7.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Get LATEST driver version for 90.0.4430
# Trying to download new driver from https://chromedriver.storage.googleapis.com/90.0.4430.24/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24]
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# Extracting pages(3, 4, 5)

# for holding the resultant list
element_list71 = []
  
for page in range(3, 6, 1):
    
    page_url71 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    driver71 = webdriver.Chrome(ChromeDriverManager().install())
    driver71.get(page_url71)
    rating71 = driver71.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    review71 = driver71.find_elements_by_xpath("//p[@class='_2-N8zT']")
    full_review71 = driver71.find_elements_by_xpath("//div[@class='t-ZTKy']")
  
    for i in range(len(rating71)):
        element_list71.append([rating71[i].text, review71[i].text, full_review71[i].text])
  
print(element_list71)
  
#closing the driver
driver71.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# Extracting pages(6,7)

# for holding the resultant list
element_list72 = []
  
for page in range(6, 8, 1):
    
    page_url72 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    driver72 = webdriver.Chrome(ChromeDriverManager().install())
    driver72.get(page_url72)
    rating72 = driver72.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    review72 = driver72.find_elements_by_xpath("//p[@class='_2-N8zT']")
    full_review72 = driver72.find_elements_by_xpath("//div[@class='t-ZTKy']")
  
    for i in range(len(rating72)):
        element_list72.append([rating72[i].text, review72[i].text, full_review72[i].text])
  
print(element_list72)
  
#closing the driver
driver72.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# Extracting pages(8,9)

# for holding the resultant list
element_list73 = []
  
for page in range(8, 10, 1):
    
    page_url73 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    driver73 = webdriver.Chrome(ChromeDriverManager().install())
    driver73.get(page_url73)
    rating73 = driver73.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    review73 = driver73.find_elements_by_xpath("//p[@class='_2-N8zT']")
    full_review73 = driver73.find_elements_by_xpath("//div[@class='t-ZTKy']")
  
    for i in range(len(rating73)):
        element_list73.append([rating73[i].text, review73[i].text, full_review73[i].text])
  
print(element_list73)
  
#closing the driver
driver73.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# Extracting pages(10, 11)

# for holding the resultant list
element_list74 = []
  
for page in range(10, 12, 1):
    
    page_url74 = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART&page=" + str(page)
    driver74 = webdriver.Chrome(ChromeDriverManager().install())
    driver74.get(page_url74)
    rating74 = driver74.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']")
    review74 = driver74.find_elements_by_xpath("//p[@class='_2-N8zT']")
    full_review74 = driver74.find_elements_by_xpath("//div[@class='t-ZTKy']")
  
    for i in range(len(rating74)):
        element_list74.append([rating74[i].text, review74[i].text, full_review74[i].text])
  
print(element_list74)
  
#closing the driver
driver74.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# creating a new list by combining all the extracted data
new_element_list_7= element_list7+element_list71+element_list72+element_list73+element_list74

# %%
new_element_list_7_=new_element_list_7[0:100]

# %%
len(new_element_list_7_)
# Out:
# 100

# %%
pd.set_option('display.max_rows', None)
pd.options.display.max_colwidth = 500
pd. set_option('display.width', 10000)

# %%
# Creating DataFrame
df7 = pd.DataFrame(new_element_list_7_, columns =['Rating', 'Review', 'Full Review'])  
df7.head(100)
# Out:
#    Rating                    Review                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Full Review
# ...

# %% [markdown]
# # <br><br> <br>Q8: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field.
# You have to scrape 4 attributes of each sneaker :
# 1. Brand
# 2. Product Description
# 3. Price
# 4. discount %

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url8= " https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off "
driver.get(url8)

# %%
# importing necessary packages
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
  
# for holding the resultant list
element_list8 = []
  
for page in range(1, 4, 1):
    
    page_url8 = "https://www.flipkart.com/search?q=sneakers&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=" + str(page)
    driver8 = webdriver.Chrome(ChromeDriverManager().install())
    driver8.get(page_url8)
    title8 = driver8.find_elements_by_xpath("//div[@class='_2WkVRV']")
    description8 = driver8.find_elements_by_xpath("//a[@target='_blank']")
    price8 = driver8.find_elements_by_xpath("//div[@class='_30jeq3']")
    discount8 = driver8.find_elements_by_xpath("//div[@class='_3Ay6Sb']/span")

  
    for i in range(len(discount8)):
        element_list8.append([title8[i].text, description8[i].text, price8[i].text, discount8[i].text])
  
print(element_list8)
  
#closing the driver
driver8.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
new_element_list8= element_list8[0:100]

# %%
len(new_element_list8)
# Out:
# 100

# %%
# creating dataframe
df8 = pd.DataFrame(new_element_list8, columns =['Brand Name', 'Description', 'Price(in Rs.)', 'Discount'])  
df8.head(100)
# Out:
#              Brand Name                                                 Description Price(in Rs.) Discount
# 0                DUCATI                                                                    ₹1,924  47% off
# 1                DUCATI                                            Sneakers For Men        ₹1,199  67% off
# 2          Robbie jones                  ₹1,924₹3,69947% off\nOr Pay ₹1,827 + \n 97          ₹379  62% off
# 3          Robbie jones                                                                      ₹474  52% off
# 4              HOTSTYLE                                            Sneakers For Men          ₹283  43% off
# 5               Numenzo                  ₹1,199₹3,69967% off\nOr Pay ₹1,139 + \n 60          ₹398  60% off
# 6                ORICUM                                                                      ₹377  62% off
# 7          Stefano Rads              Casual Sneakers Shoes For Men Sneakers For Men          ₹242  65% off
# ...

# %% [markdown]
# # <br><br><br> Q9: Go to the link - https://www.myntra.com/shoes
# * Set Price filter to “Rs. 6649 to Rs. 13099” , Color filter to “Black”, as shown inthe below image
# * And then scrape First 100 shoes data you get. The data should include “Brand” of the shoes , Short Shoe description, price of the shoe as shown in the below image

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url= " https://www.myntra.com/shoes "
driver.get(url)

# %%
# applying price filter
price_filter=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label")[0].click()

# %%
# applying color filter
color_filter=driver.find_elements_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label")[0].click()

# %%
# importing necessary packages
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
  
# for holding the resultant list
element_list = []
  
for p in range(1, 3, 1):
    
    page_url = "https://www.myntra.com/shoes?f=Color%3ABlack_36454f&plaEnabled=false&rf=Price%3A7649.0_15099.0_7649.0%20TO%2015099.0&p=" + str(p)
    driver1 = webdriver.Chrome(ChromeDriverManager().install())
    driver1.get(page_url)
    title = driver1.find_elements_by_xpath("//h3[@class='product-brand']")
    price = driver1.find_elements_by_xpath("//div[@class='product-price']")
    description = driver1.find_elements_by_xpath("//h4[@class='product-product']")
  
    for i in range(len(title)):
        element_list.append([title[i].text, price[i].text, description[i].text])
  
print(element_list)
  
#closing the driver
driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
# Creating DataFrame
df9 = pd.DataFrame(element_list, columns =['Brand Name', 'Price(in Rs.)', 'Description'])  
df9
# Out:
#               Brand Name                Price(in Rs.)                             Description
# 0                Saint G                    Rs. 11800                    Leather Heeled Boots
# 1                   Nike                    Rs. 11495          AIR ZOOM PEGASUS Running Shoes
# 2                   Nike  Rs. 14955Rs. 17595(15% OFF)               Unisex LEBRON XVIII Shoes
# 3                   ALDO                    Rs. 14999                   Leather Solid Loafers
# 4        PUMA Motorsport                     Rs. 7999           Unisex Mercedes Running Shoes
# 5                   Nike                    Rs. 12995            Men KD13 EP Basketball Shoes
# 6                   Nike                    Rs. 12495             Men JORDAN DELTA Basketball
# 7                   ALDO                     Rs. 9999                            Men Sneakers
# 8                   Nike  Rs. 11246Rs. 14995(25% OFF)               Men JOYRIDE Running Shoes
# ...

# %% [markdown]
# # <br><br><br> Q10: Go to webpage https://www.amazon.in/
# * Enter “Laptop” in the search field and then click the search icon.
# After setting the filters scrape first 10 laptops data. You have to scrape 3 attributes
# for each laptop:
# 1. title
# 2. Ratings
# 3. Price

# %%
# lets first  connect to webdriver
driver= webdriver.Chrome(r"C:\\Users\\Lenovo\Documents\chromedriver.exe")

# %%
url10= " https://www.amazon.in/ "
driver.get(url10)

# %%
# finding element by job search bar
search_item=driver.find_element_by_id('twotabsearchtextbox')
search_item
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="f408c3c7f35e97465676608313fe90c6", element="96a89c7f-6be5-4536-beb9-55a0f0a6f75c")>

# %%
# write on search bar
search_item.send_keys("Laptop")

# %%
# applying filter
cpu_filter=driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div[3]/span/div[1]/span/div/div/div[6]/ul[1]/li[12]/span/a/span")

# %%
#applying filter
cpu_filter1=driver.find_elements_by_xpath("/html/body/div[1]/div[2]/div[1]/div/div[2]/div/div[3]/span/div[1]/span/div/div/div[6]/ul[1]/li[13]/span/a/span")

# %%
element_list10 = []
  
for page in range(1, 3, 1):
    
    page_url10 = "https://www.amazon.in/s?k=Laptop&rh=n%3A1375424031%2Cp_n_feature_thirteen_browse-bin%3A12598163031&dc&qid=1621627633&rnid=12598141031&ref=sr_nr_p_n_feature_thirteen_browse-bin_12" + str(page)
    driver10 = webdriver.Chrome(ChromeDriverManager().install())
    driver10.get(page_url10)
    title10 = driver10.find_elements_by_xpath("//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']")
    price10 = driver10.find_elements_by_xpath("//span[@class='a-price-whole']")
    rating10 = driver10.find_elements_by_xpath("//i[@class='a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom']/span")
  
    for i in range(len(rating10)):
        element_list10.append([title10[i].text, price10[i].text, rating10[i].text])
  
print(element_list10)
  
#closing the driver
driver10.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
#
#
# ====== WebDriver manager ======
# Current google-chrome version is 90.0.4430
# Get LATEST driver version for 90.0.4430
# Driver [C:\Users\Lenovo\.wdm\drivers\chromedriver\win32\90.0.4430.24\chromedriver.exe] found in cache
# ...

# %%
len(element_list10)
# Out:
# 10

# %%
# Creating DataFrame
df10 = pd.DataFrame(element_list10, columns =['Laptop Name', 'Price(in Rs.)', 'Rating'])  
df10
# Out:
#                                                                                                                                                                                                  Laptop Name Price(in Rs.) Rating
# 0                Lenovo Yoga Slim 7 10th Gen Intel Core i7 14 inch Full HD IPS Thin and Light Laptop (8GB/512GB SSD/Windows 10/MS Office 2019/NVIDIA MX350 2GB GDDR5 Graphics/Slate Grey/1.55Kg), 82A1009KIN        83,990
# 1    Lenovo Yoga 7 11th Gen Intel Core i7 14" (35.56cms) Full HD IPS 2-in-1 Touchscreen Laptop (16GB/512GB SSD/Windows 10/MS Office 2019/Fingerprint Reader/Slate Grey/Aluminium Surface/1.43Kg), 82BH004HIN      1,07,499
# 2     Dell Inspiron 7306 i7 11th Gen, x360 13.3" 4K UHD Touch Laptop, 16GB RAM, 512GB SSD + 32GB Optane, Windows 10 Home, Intel Iris XE Graphics, Dell Active Pen, Dell Waves MaxxAudio, Element Black Color      1,17,999
# ...
